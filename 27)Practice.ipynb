# %% [markdown]
# Data structure
# - list
# - tupple
# - dictionary
# - sets
#
# string:
#     methods, etc
#
# Loops:
# - while loop
# - for loop
#
# Conditions:
# - simple if else
# - multiple if else
# - nested if else
#
# Exception Handling:
# - try except
#
# Functions:
#
# File Handling:
# - Read write append

# %% [markdown]
# # OOP (OBJECT OREIENTED PROGRAMMING)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Class:
# - Blueprint, template
#
# objects:
# - Copies of that class

# %% [markdown]
# Realme5i:
#
# Attributes / Characteristics / Features (variables):
# - color, size, display screen, memory
#
# Functionality (methods/fucntions):
# - can call, can text, can take pictures and videos and so on

# %%
name = 'pakistan'
print(type(name))
# Out:
# <class 'str'>

# %%
class Car():
    make = 'Honda'
    model = 'Civic'
    year =  2020

# %%
car1 = Car()

# %%
car1.make
# Out:
# 'Honda'

# %%
car1.model
# Out:
# 'Civic'

# %%
car1.year
# Out:
# 2020

# %%
Car()

# %%
car2 = Car()

# %%
car2.make
# Out:
# 'Honda'

# %%
car2.model
# Out:
# 'Civic'

# %%
class Car:
    # constructor / initializer
    def __init__(self,make, model, year):
        make = make
        model = model
        year =  year

# %%
car1 = Car('Honda', 'Civic',2020)

# %%
car1.make
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3872\3556740818.py in <module>
# ----> 1 car1.make
#
# AttributeError: 'Car' object has no attribute 'make'

# %%
class Car:
    def __init__(self,make, model, year):
        self.make = make
        self.model = model
        self.year =  year

# %%
car1 = Car('Honda', 'Civic', 2020)

# %%
car1.make
# Out:
# 'Honda'

# %%
car1.model
# Out:
# 'Civic'

# %%
car2 = Car('Toyota', 'yaris', 2025)

# %%
car2.make
# Out:
# 'Toyota'

# %%
car2.model
# Out:
# 'yaris'

# %%
print(car1.make)
print(car2.make)
# Out:
# Honda
# Toyota

# %%
class Car(make, model, year):
    # def __init__(self,make, model, year):
    make = make
    model = model
    year =  year
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 class Car(make, model, year):
#       2     # def __init__(self,make, model, year):
#       3     make = make
#       4     model = model
#
# NameError: name 'make' is not defined

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Car:
    def __init__(self,make, model, year):
        # Attributes
        self.make = make
        self.model = model
        self.year =  year 
    
    # Methods
    def apply_accelerator(self):
        print('Accelerator is applied')
    
    def apply_breaks(self):
        print('Brakes are applied')

# %%
new_car = Car('Honda', 'Civic',2020)

# %%
new_car.apply_breaks()
# Out:
# Brakes are applied

# %%
new_car.apply_accelerator()
# Out:
# Accelerator is applied

# %%
another_car = Car('BMW', 'Camry', 2022)

# %%
another_car.apply_accelerator()
# Out:
# Accelerator is applied
