# %% [markdown]
# # File Handling (in python)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
f = open('practice.txt')

# %%
f
# Out:
# <_io.TextIOWrapper name='practice.txt' mode='r' encoding='UTF-8'>

# %%
content = f.read()

# %%
print(content)

# %%
print(type(content))
# Out:
# <class 'str'>

# %%
f.close()

# %%
print(content)
# Out:
# Whatâ€™s better than stories to inculcate moral values in children happily? Stories, at bedtime or during the day, are a great way of bonding with children and teaching them lessons. But how does the bonding happen? Well, when we recite stories to children in a way they understand (*we mean by making faces and cute sounds*), they start developing the habit of listening to their parents, which in later years, helps a lot. Fables like the â€˜Thirst Crowâ€™ story in English are short and easy to understand for children that send profound lessons.

# %%
f = open(r"C:\Users\SMIT\Desktop\helloworld.txt")

# %%
print(f.read())
# Out:
# Python aur bhi kuch
# second line

# %%
f.read()
# Out:
# ''

# %%
f.close()

# %%
f = open('newfile.txt', 'w')

# %%
f.write('Writing content in file using python')
# Out:
# 36

# %%
f.close()

# %%
f = open('practice.txt', 'w')

# %%
f.write('we are testing this file')
# Out:
# 24

# %%
f.close()

# %%
f = open(r"C:\Users\SMIT\Desktop\desktop.txt", 'w')

# %%
f.write('This is my second line')
# Out:
# 22

# %%
f.close()

# %%
f = open('practice.txt', 'a')

# %%
f.write('\nUSING APPEND MODE')
# Out:
# 18

# %%
f.close()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
f = open('alikhan.txt', 'r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4336\872558594.py in <module>
# ----> 1 f = open('alikhan.txt', 'r')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'alikhan.txt'

# %%
f = open('alikhan.txt', 'a')

# %%
f.write('new file using append mode')
# Out:
# 26

# %%
f.close()

# %%
f = open('alikhan.txt')

# %%
content = f.read()

# %%
f.close()

# %%
content = content.replace('append', 'write')

# %%
content
# Out:
# 'new file using write mode'

# %%
f = open('alikhan.txt', 'w')

# %%
f.write(content)
# Out:
# 25

# %%
f.close()

# %%
content = f.read()

# %%
print(content)
# Out:
# Writing content in file using python

# %%
new_content = content.replace('python', 'java')

# %%
print(content)
print(new_content)
# Out:
# Writing content in file using python
# Writing content in file using java

# %%
f.close()

# %%
f = open('newfile.txt', 'w')

# %%
f.write(new_content)
# Out:
# 34

# %%
f.close()
