# %%
info = 'This is a sentence'

# %%
info
# Out:
# 'This is a sentence'

# %%
type(info)
# Out:
# str

# %%
number = 10

# %%
number.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12472\27824213.py in <module>
# ----> 1 number.upper()
#
# AttributeError: 'int' object has no attribute 'upper'

# %%
info = info.upper()

# %%
info.lower()
# Out:
# 'this is a sentence'

# %%
info.title()
# Out:
# 'This Is A Sentence'

# %%
info.capitalize()
# Out:
# 'This is a sentence'

# %%
fullname = input('Enter you full name: ').title()
fullname
# Out:
# 'Ali Khan'

# %%
fullname
# Out:
# 'Ali Khan'

# %%
fullname.isupper()
# Out:
# False

# %%
fullname.islower()
# Out:
# False

# %%
fullname.istitle()
# Out:
# True

# %%
empty_string = ''
space_string = ' ' #having space

# %%
fullname
# Out:
# 'Ali Khan'

# %%
fullname.isspace()
# Out:
# False

# %%
empty_string.isspace()
# Out:
# False

# %%
space_string.isspace()
# Out:
# True

# %%
'pakistan'
'p a k i s t a n'

# %%
'My name is ali khan 2112'
# Out:
# 20

# %%
fullname
# Out:
# 'Ali Khan'

# %%
fullname.startswith('A')
# Out:
# True

# %%
char = input('Enter the letter? ').upper()
fullname.startswith(char)
# Out:
# False

# %%
fullname.startswith('k')
# Out:
# False

# %%
fullname.endswith('n')
# Out:
# True

# %%
fullname.endswith('a')
# Out:
# False

# %%
fullname.endswith('N'.lower())
# Out:
# True
