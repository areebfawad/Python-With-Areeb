# %% [markdown]
# # Dictionary

# %%
# info = { 'key':'value' }
info = { 'name':'Areeb Fawad', 'course': 'python', 'age':19 }

# %%
type(info)
# Out:
# dict

# %%
len(info)
# Out:
# 3

# %%
info
# Out:
# {'name': 'Areeb Fawad', 'course': 'python', 'age': 19}

# %%
info
# Out:
# {'name': 'Areeb Fawad', 'course': 'python', 'age': 19}

# %%
data = {
    "Virat Kohli": 'Off side delivery', 
    "Babar Azam": 'Cricket', 
    "Haris Rauf": 'Bowling', 
    10: 'Shahid Afridi',
    [123]: 'List value'
    }
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 data = {
#       2     "Virat Kohli": 'Off side delivery',
#       3     "Babar Azam": 'Cricket',
#       4     "Haris Rauf": 'Bowling',
#       5     10: 'Shahid Afridi',
#       6     [123]: 'List value'
#       7     }
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# No, a Python list cannot be directly used as a key in a dictionary. Dictionary keys in Python must be hashable and immutable. Lists are mutable, meaning their contents can be changed after they are created, and therefore they are not hashable.

# %%
info
# Out:
# {'name': 'Ali khan', 'course': 'python', 'age': 23}

# %%
cities = ['karachi', 'lahore', 'murre']
cities[1] = 'Larkana'
cities
# Out:
# ['karachi', 'Larkana', 'murre']

# %%
info['city'] = 'Karachi'
info
# Out:
# {'name': 'Areeb Fawad', 'course': 'python', 'age': 19, 'city': 'Karachi'}

# %%
info[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 info[0]
#
# KeyError: 0

# %%
info['name']
# Out:
# 'Areeb Fawad'

# %%
info['city'] = 'waseem bhai'
info
# Out:
# {'name': 'Areeb Fawad', 'course': 'python', 'age': 19, 'city': 'waseem bhai'}

# %%
info.update({'campus':'gulshan', 'city':'karachi'})

# %% [markdown]
# ## How to remove a value from a dictionary

# %%
del info['age']

# %%
info
# Out:
# {'name': 'Areeb Fawad',
#  'course': 'python',
#  'city': 'karachi',
#  'campus': 'gulshan'}

# %%
topi =info.pop('Topi')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 topi =info.pop('Topi')
#
# KeyError: 'Topi'

# %%
topi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 topi
#
# NameError: name 'topi' is not defined

# %%
popitem_value = info.popitem()

# %%
popitem_value
# Out:
# ('campus', 'gulshan')

# %%
info
# Out:
# {'name': 'Areeb Fawad', 'course': 'python', 'city': 'karachi'}

# %%
info.items()
# Out:
# dict_items([('name', 'Areeb Fawad'), ('course', 'python'), ('city', 'karachi')])

# %%
topi = input('Enter your topi')
reason = input('Enter your topi reason')

# %%
info[topi] = reason

# %%
info
# Out:
# {'name': 'Areeb Fawad',
#  'course': 'python',
#  'city': 'karachi',
#  'washroom': 'jana ha'}

# %%
list(info.keys())
# Out:
# ['name', 'course', 'city', 'washroom']

# %%
list(info.values())
# Out:
# ['Areeb Fawad', 'python', 'karachi', 'jana ha']

# %%
old_items = list(info.items())
old_items
# Out:
# [('name', 'Areeb Fawad'),
#  ('course', 'python'),
#  ('city', 'karachi'),
#  ('washroom', 'jana ha')]

# %%
info['name']
# Out:
# 'Areeb Fawad'

# %%
info['Name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 info['Name']
#
# KeyError: 'Name'

# %%
info
# Out:
# {'name': 'Areeb Fawad',
#  'course': 'python',
#  'city': 'karachi',
#  'washroom': 'jana ha'}

# %%
info.get('name')
# Out:
# 'Areeb Fawad'

# %%
info.get('Name')

# %%
info['Topi'] = None

# %%
info
# Out:
# {'name': 'Areeb Fawad',
#  'course': 'python',
#  'city': 'karachi',
#  'washroom': 'jana ha',
#  'Topi': None}

# %%
print(info.get('Topi'))
# Out:
# None

# %%
print(info.get('name'))
print(info.get('Name', 'Traffic bht tha'))
print(info.get('Topi', 'Traffic bht tha'))
# Out:
# Areeb Fawad
# Traffic bht tha
# None

# %%
info
# Out:
# {'name': 'Areeb Fawad',
#  'course': 'python',
#  'city': 'karachi',
#  'washroom': 'jana ha',
#  'Topi': None}

# %%
info.get('Name', 'Traffic bht tha')
# Out:
# 'Traffic bht tha'

# %%
values = list(info.values())
print(values.index('Ali khan'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 2
#       1 values = list(info.values())
# ----> 2 print(values.index('Ali khan'))
#
# ValueError: 'Ali khan' is not in list

# %%
keys = list(info.keys())
print(keys[0])
# print(values)
# Out:
# name

# %%
print(values)
print(f"Index of Ali khan in the list {values.index('Ali khan')}")
print(keys)
print(f'The key of value "Ali khan" is: {keys[0]}')
# Out:
# ['Areeb Fawad', 'python', 'karachi', 'jana ha', None]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 2
#       1 print(values)
# ----> 2 print(f"Index of Ali khan in the list {values.index('Ali khan')}")
#       3 print(keys)
#       4 print(f'The key of value "Ali khan" is: {keys[0]}')
#
# ValueError: 'Ali khan' is not in list

# %%
info = {'name': 'Ali khan', 'course': 'python', 'city': 'karachi', 'Topi': None}

# %%
info_copy = info.copy()
print(info)
print(info_copy)
# Out:
# {'name': 'Ali khan', 'course': 'python', 'city': 'karachi', 'Topi': None}
# {'name': 'Ali khan', 'course': 'python', 'city': 'karachi', 'Topi': None}

# %%
info_copy.pop('Topi')

# %%
print(info)
print(info_copy)
# Out:
# {'name': 'Ali khan', 'course': 'python', 'city': 'karachi', 'Topi': None}
# {'name': 'Ali khan', 'course': 'python', 'city': 'karachi'}

# %%
another_info_copy = info

# %%
another_info_copy['Testing'] = 'any value'

# %%
print(info)
print(another_info_copy)
# Out:
# {'name': 'Ali khan', 'course': 'python', 'city': 'karachi', 'Topi': None, 'Testing': 'any value'}
# {'name': 'Ali khan', 'course': 'python', 'city': 'karachi', 'Topi': None, 'Testing': 'any value'}

# %%
another_info_copy is info
# Out:
# True

# %%
another_info_copy is info_copy
# Out:
# False

# %%
info.clear()
# Out:
# {}
