# %%
#ipynb stands for interactive python notebook

# %% [markdown]
# Basic data Type:
# - String
# - Integer
# - Float
# - Boolean

# %%
fname = 'Areeb '
lname = 'Fawad'
print(fname, lname)
# Out:
# Areeb  Fawad

# %%
fname
# Out:
# 'Areeb '

# %%
print(fname, lname)
# Out:
# Areeb  Fawad

# %% [markdown]
# # User Input using input() function

# %%
value = input('Enter any value')

# %%
print(value)
print(type(value))
# Out:
# 23
# <class 'str'>

# %%
fname = input('Enter first name: ')
lname = input('Enter second name: ')
print(fname, lname)
# Out:
# Areeb Fawad

# %%
num1 = int(input('Enter first number: '))
num2 = int(input('Enter second number: '))

result = num1 + num2
print('This is your result',result)
# Out:
# This is your result 5

# %%
print(2 + 1)
print(2 + 1) #Concatenation
print('+') #Concatenation
# print(2 '+' 1) this is not the right way( invalid syntax)
# Out:
# 3
# 3
# +

# %% [markdown]
# # Type Casting

# %%
int('a')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_648\2121867093.py in <module>
# ----> 1 int('a')
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
num = int('2')
type(num)
# Out:
# int

# %%
num = '23.3'
result = float(num)
print(result, type(result))
# Out:
# 23.3 <class 'float'>

# %%
num = 23
result = str(num)
print('The value of result is',result, 'and the type of result is', type(result))
# Out:
# The value of result is 23 and the type of result is <class 'str'>

# %%
print(bool(0))
print(bool(1))
print(bool(23))
print(bool(-23))
print(bool(-23.3))
print(bool(23.3))
print(bool(0.3))
# Out:
# False
# True
# True
# True
# True
# True
# True

# %%
print(bool('kuch bhi hoskta hai'))
print(bool(' '))
print(bool(''))
# Out:
# True
# True
# False

# %% [markdown]
# # String

# %%
num = 23
result = str(num)
print('The value of result is',result, 'and the type of result is', type(result))
# Out:
# The value of result is 23 and the type of result is <class 'str'>

# %% [markdown]
# # String Formatting

# %%
num = 23
print('The value of result is',num, 'and the type of result is', type(num))
print(f'The value of result is {num} and the type of result is {type(num)}') #string formatting
# Out:
# The value of result is 23 and the type of result is <class 'int'>
# The value of result is 23 and the type of result is <class 'int'>

# %%
age = 23
course  = 'python'
campus = 'smit'
print(f'I am {age} years old and i study {course} in {campus} gulshan campus')
# Out:
# I am 23 years old and i study python in smit gulshan campus

# %%
print('this is first line 
this is second line')
# Out:
#   File "C:\Users\SMIT\AppData\Local\Temp\ipykernel_648\2252152374.py", line 1
#     print('this is first line
#                               ^
# SyntaxError: EOL while scanning string literal

# %%
print('dkfjdkfjdk')
