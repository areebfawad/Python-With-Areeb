# %%
fullname = 'Areeb Fawad'

# %%
fullname.count('areeb')
# Out:
# 0

# %%
fullname.count('a')
# Out:
# 2

# %%
info = 'My name is nabeel sadiq, i live in Lahore and Lahore is a beautiful city and i dont want to leave Lahore'

# %%
info.count('Lahore')
# Out:
# 3

# %%
start = info.find('i live')

# %%
end = info.find('city') + len('city') -1

# %%
info.count('city')
# Out:
# 1

# %% [markdown]
# # String Slicing

# %%
# info[start: end+1] ----> start=inclusive, end = exclusive(you need to add 1)
sliced_info = info[start : end +1]
sliced_info
# Out:
# 'i live in Lahore and Lahore is a beautiful city'

# %%
info
# Out:
# 'My name is nabeel sadiq, i live in Lahore and Lahore is a beautiful city and i dont want to leave Lahore'

# %% [markdown]
# # List

# %%
all_names = ['ali khan', 'waseem bhai', 'sattar bhai', 'ghafar bhai', 'chahat bhai']

# %%
type(all_names)
# Out:
# list

# %%
len(all_names)
# Out:
# 5

# %%
# How to access a single value from a list

# %%
all_names[0]
# Out:
# 'ali khan'

# %%
all_names[4]
# Out:
# 'chahat bhai'

# %%
all_names[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 all_names[5]
#
# IndexError: list index out of range

# %% [markdown]
# # Slicing List

# %%
all_names[0:3]
# Out:
# ['ali khan', 'waseem bhai', 'sattar bhai']

# %%
all_names[1:4]
# Out:
# ['waseem bhai', 'sattar bhai', 'ghafar bhai']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# all_names[start: end + 1 : step]
all_names[0:5:4]
# Out:
# ['ali khan', 'chahat bhai']

# %%
all_names[0: 5 : 2]
# Out:
# ['ali khan', 'sattar bhai', 'chahat bhai']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
all_names[-4: -1]
# Out:
# ['waseem bhai', 'sattar bhai', 'ghafar bhai']

# %%
all_names[-1]
# Out:
# 'chahat bhai'

# %%
['ali khan', 'waseem bhai', 'sattar bhai']
sliced_list = all_names[0:3]
sliced_list[::-1]
# Out:
# ['sattar bhai', 'waseem bhai', 'ali khan']

# %%
all_names[::-1]
# Out:
# ['chahat bhai', 'ghafar bhai', 'sattar bhai', 'waseem bhai', 'ali khan']

# %%
info[::-1]
# Out:
# 'erohaL evael ot tnaw tnod i dna ytic lufituaeb a si erohaL dna erohaL ni evil i ,qidas leeban si eman yM'

# %%
value = input("Enter anything but it will be limited to 6 characters")[0:7]

# %%
value
# Out:
# 'my name'

# %%
all_names.append('Bobie Ajam')

# %%
all_names.append('Fakhar', 'Amir')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15020\1662989487.py in <module>
# ----> 1 all_names.append('Fakhar', 'Amir')
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
all_names.append('Fakhar')

# %%
all_names
# Out:
# ['ali khan',
#  'waseem bhai',
#  'sattar bhai',
#  'ghafar bhai',
#  'chahat bhai',
#  'Bobie Ajam',
#  'Fakhar']

# %%
cric = input('Enter any cricketer: ')

# %%
cric
# Out:
# 'Amir'

# %%
all_names.append(cric)

# %%
all_names
# Out:
# ['ali khan',
#  'waseem bhai',
#  'sattar bhai',
#  'ghafar bhai',
#  'chahat bhai',
#  'Bobie Ajam',
#  'Fakhar',
#  'Amir']
