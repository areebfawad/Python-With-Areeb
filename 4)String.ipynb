# %%
num1 = 5
num2 = 10

# %%
userInput = int(input("Enter your option: "))
print(userInput)

if userInput == num1:
    print("Num1 is equals to your input")
else
# Out:
# 22

# %%
# Rayyan

# %%
# Areeb Fawad

# %% [markdown]
# # String

# %%
# f-string

# %%
fname = input('Enter your first name: ')
lname = input('Enter your last name: ')
course = input('Enter your course name: ')
email = input('Enter your email name: ')

print(f'I am {fname} {lname} wants to enroll in this course "{course}" my email address is {email}')
# Out:
# I am Rayyan Shah wants to enroll in this course "Python" my email address is shahsahab@gmail.com\

# %%
fname = 'chahat'

# %% [markdown]
# ## String's Methods

# %%
name = 'chahat fateh ali khan'

# %%
# Methods are those functions that belong to a certain class
print('#')
# Out:
# #

# %%
upper_name = name.upper()

# %%
print(upper_name)
print(name)
# Out:
# CHAHAT FATEH ALI KHAN
# chahat fateh ali khan

# %%
print(name)
# Out:
# chahat fateh ali khan

# %%
# Immutable Data Type

# %% [markdown]
# ![image.png](attachment:image.png)
