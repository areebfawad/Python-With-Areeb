# %%
print(2+2)
print(2+4)
print(2+2+2+4)
# Out:
# 4
# 6
# 10

# %% [markdown]
# # Variables
# - Container to store some value

# %%
num1 = 2 + 2
num2 = 5 + 6
result = num1 + num2
print(num1)
print(num2)
print(result)
# Out:
# 4
# 11
# 15

# %%
# A value 'Areeb' is assigned to a variable fname
# = is a assignment operator
fname = 'Areeb'
lname = 'Fawad'
print(fname,lname)
# Out:
# Areeb Fawad

# %%
print(type(fname))
print(type(lname))
# Out:
# <class 'str'>
# <class 'str'>

# %%
print(type(num1))
print(type(num2))
print(type(result))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
print(id(fname))
print(id(lname))
# Out:
# 1965228949440
# 1965225245936

# %%
print(fname)
# Out:
# Areeb

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
fname
# Out:
# 'Areeb'

# %%
fname = 'Moin'

# %%
id(fname)
# Out:
# 1965229310288

# %%
first_name = 'areeb'
second_name = 'areeb'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(id(first_name))
print(id(second_name))
# Out:
# 1965195886528
# 1965195886528
