# %%
cities = ['Karachi', 'Lahore', 'Quetta', 'Murre', 'Larkana']

# %%
cities.count('Karachi')
# Out:
# 1

# %%
cities.reverse()

# %%
cities.sort()

# %%
cities
# Out:
# ['Karachi', 'Lahore', 'Larkana', 'Murre', 'Quetta']

# %%
fruits = ['cherry', 'mango', 'apple', 'banana','grapes']

# %%
a b c d e f g h i j k l m
# Out:
#   File "C:\Users\SMIT\AppData\Local\Temp\ipykernel_12004\1783227398.py", line 1
#     a b c d e f g h i j k l m
#       ^
# SyntaxError: invalid syntax

# %%
fruits.sort(reverse=True)

# %% [markdown]
# # Copy By Value (shallow copy)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
copy_fruits = fruits.copy()
copy_fruits
# Out:
# ['mango', 'grapes', 'cherry', 'banana', 'apple']

# %%
print(fruits)
print(copy_fruits)
# Out:
# ['mango', 'grapes', 'cherry', 'banana', 'apple']
# ['mango', 'grapes', 'cherry', 'banana', 'apple']

# %%
copy_fruits.append('kiwi')

# %%
copy_fruits
# Out:
# ['mango', 'grapes', 'cherry', 'banana', 'apple', 'kiwi']

# %%
fruits
# Out:
# ['mango', 'grapes', 'cherry', 'banana', 'apple']

# %% [markdown]
# # Copy by Reference

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# cites = [dlkfjdkljfkldsjfklasdj]
# another_cites = cities

# %%
another_fruits = fruits

# %%
another_fruits.append('pear')

# %%
another_fruits
# Out:
# ['mango', 'grapes', 'cherry', 'banana', 'apple', 'pear']

# %%
fruits
# Out:
# ['mango', 'grapes', 'cherry', 'banana', 'apple', 'pear']

# %%
print(id(fruits))
print(id(another_fruits))
print(id(copy_fruits))
# Out:
# 2675837726976
# 2675837726976
# 2675837728512

# %% [markdown]
# ## Split and join (string remaining methods)

# %%
email = 'alikhan@gmail.com'

# %%
print(email.split('@'))
print(email.split('@')[0])
# Out:
# ['alikhan', 'gmail.com']
# alikhan

# %%
info = 'alikhan-python-smit-karachi'

# %%
split_list = info.split('-')

# %%
'_'.join(split_list)
# Out:
# 'alikhan_python_smit_karachi'

# %%
lst = list()

# %%
lst
# Out:
# []

# %%
list('hello')
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
lst =  [3, 5, 25, 1, 3]
max(lst)
min(lst)
# Out:
# 1

# %%
names = ['Amir', 'Bear', 'Charlton', 'Daman']
print(names[-1][-3])
# Out:
# m

# %%
[1, 3, 2]*2
# Out:
# [1, 3, 2, 1, 3, 2]

# %%
list1 = [11, 2, 23]
list2 = [11, 2, 45]
print(list1 < list2)
# Out:
# True
