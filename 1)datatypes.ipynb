# %%
print('Hello world')
print('This is our first class')
print('this is our third line')
print('this is our fourth line')
# Out:
# Hello world
# This is our first class
# this is our third line
# this is our fourth line

# %%
print('Hello world',end=' ')
print('Areeb Fawad')
print('chahat fateh Khan')
# Out:
# Hello world Areeb Fawad
# chahat fateh Khan

# %%
print('Fakhar','Bobzie','Rizwan')
# Out:
# Fakhar Bobzie Rizwan

# %%
print('Fakhar','Bobzie','Rizwan', sep='------')
print('Fakhar','Bobzie','Rizwan', sep='------')
print('Fakhar','Bobzie','Rizwan', sep='\n')
# Out:
# Fakhar------Bobzie------Rizwan
# Fakhar
# Bobzie
# Rizwan

# %%
print('This is our first line \nThis is our second line')
# Out:
# This is our first line
# This is our second line

# %%
print('AbdulRehman','AreebFawad', sep='------')
# Out:
# AbdulRehman------AreebFawad

# %%
print(4+2)
print(4-2)
print(4*2)
print(4/2)
# Out:
# 6
# 2
# 8
# 2.0

# %%
print(23.3+2)
print(2+3)
print(2+3)
# Out:
# 25.3
# 5

# %%
print('2+3')
print(2+3)
# Out:
# 2+3
# 5

# %% [markdown]
# # Types of Data (Data Types)

# %% [markdown]
# - String --- Text
# - Integer --- Whole Number
# - Floating point data --- Decimal Number
# - Boolean --- True and False

# %%
print('This is a text data')
print(234)
print(234.3)
print(True, False)
# Out:
# This is a text data
# 234
# 234.3
# True False

# %%
print(type('areeb fawad'))
print(type(12))
print(type(12.3))
print(type(True))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
